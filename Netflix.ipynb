# %%
import pandas as pd

# %%
df=pd.read_csv(r"netflix_movies_detailed_up_to_2025.csv")

# %%
df
# Out:
#        show_id   type                                         title  \
# 0        10192  Movie                           Shrek Forever After
# 1        27205  Movie                                     Inception
# 2        12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3        38757  Movie                                       Tangled
# 4        10191  Movie                      How to Train Your Dragon
# ...        ...    ...                                           ...
# 15995  1440286  Movie         Festival de Viña del Mar 2025: Ha*Ash
# 15996  1271724  Movie                                 Man and Woman
# 15997  1426364  Movie              Night of the Dead Sorority Babes
# 15998  1411248  Movie                               A Dunces Burden
# 15999  1405742  Movie                                Portal to Hell
#
#                                     director  \
# 0                              Mike Mitchell
# 1                          Christopher Nolan
# ...

# %%
# HEAD
df.head()
# Out:
#    show_id   type                                         title  \
# 0    10192  Movie                           Shrek Forever After
# 1    27205  Movie                                     Inception
# 2    12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3    38757  Movie                                       Tangled
# 4    10191  Movie                      How to Train Your Dragon
#
#                       director  \
# 0                Mike Mitchell
# 1            Christopher Nolan
# 2                  David Yates
# 3   Byron Howard, Nathan Greno
# 4  Chris Sanders, Dean DeBlois
#
#                                                 cast  \
# 0  Mike Myers, Eddie Murphy, Cameron Diaz, Antoni...
# 1  Leonardo DiCaprio, Joseph Gordon-Levitt, Ken W...
# 2  Daniel Radcliffe, Emma Watson, Rupert Grint, T...
# 3  Mandy Moore, Zachary Levi, Donna Murphy, Ron P...
# 4  Jay Baruchel, Gerard Butler, Craig Ferguson, A...
#
# ...

# %%
# TAIL
df.tail()
# Out:
#        show_id   type                                  title  \
# 15995  1440286  Movie  Festival de Viña del Mar 2025: Ha*Ash
# 15996  1271724  Movie                          Man and Woman
# 15997  1426364  Movie       Night of the Dead Sorority Babes
# 15998  1411248  Movie                        A Dunces Burden
# 15999  1405742  Movie                         Portal to Hell
#
#                                     director  \
# 15995                                    NaN
# 15996                          Vladimir Kott
# 15997  Angel Nichole Bradford, Steve Hermann
# 15998                           Daniel Kowal
# 15999                             Woody Bess
#
#                                                     cast  \
# 15995                                             Ha*ash
# 15996  Anna Kotova, Stepan Devonin, Pavel Derevyanko,...
# 15997  Jessa Flux, Lynn Lowry, Angel Nichole Bradford...
# 15998                           Riley G, Mitchel Corrado
# ...

# %%
# SHAPE
df.shape
# Out:
# (16000, 18)

# %%
# DATA SIZE
df.size
# Out:
# 288000

# %%
# COLUMN
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'genres', 'language',
#        'description', 'popularity', 'vote_count', 'vote_average', 'budget',
#        'revenue'],
#       dtype='object')

# %%
# DATA TYPES
df.dtypes
# Out:
# show_id           int64
# type             object
# title            object
# director         object
# cast             object
# country          object
# date_added       object
# release_year      int64
# rating          float64
# duration        float64
# genres           object
# language         object
# description      object
# popularity      float64
# vote_count        int64
# vote_average    float64
# budget            int64
# revenue           int64
# dtype: object

# %%
# INFO
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       16000 non-null  int64
#  1   type          16000 non-null  object
#  2   title         16000 non-null  object
#  3   director      15868 non-null  object
#  4   cast          15796 non-null  object
#  5   country       15534 non-null  object
#  6   date_added    16000 non-null  object
#  7   release_year  16000 non-null  int64
#  8   rating        16000 non-null  float64
#  9   duration      0 non-null      float64
#  10  genres        15893 non-null  object
#  11  language      16000 non-null  object
#  12  description   15868 non-null  object
#  13  popularity    16000 non-null  float64
#  14  vote_count    16000 non-null  int64
#  15  vote_average  16000 non-null  float64
#  16  budget        16000 non-null  int64
#  17  revenue       16000 non-null  int64
# ...

# %%
# FIND THE DUPLICATE AND REMOVE IT
df.head()
# Out:
#    show_id   type                                         title  \
# 0    10192  Movie                           Shrek Forever After
# 1    27205  Movie                                     Inception
# 2    12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3    38757  Movie                                       Tangled
# 4    10191  Movie                      How to Train Your Dragon
#
#                       director  \
# 0                Mike Mitchell
# 1            Christopher Nolan
# 2                  David Yates
# 3   Byron Howard, Nathan Greno
# 4  Chris Sanders, Dean DeBlois
#
#                                                 cast  \
# 0  Mike Myers, Eddie Murphy, Cameron Diaz, Antoni...
# 1  Leonardo DiCaprio, Joseph Gordon-Levitt, Ken W...
# 2  Daniel Radcliffe, Emma Watson, Rupert Grint, T...
# 3  Mandy Moore, Zachary Levi, Donna Murphy, Ron P...
# 4  Jay Baruchel, Gerard Butler, Craig Ferguson, A...
#
# ...

# %%
# DUPLICATE VALUE
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, genres, language, description, popularity, vote_count, vote_average, budget, revenue]
# Index: []

# %%
# IF DUPLICATE OCCURS
df.drop_duplicates()
# Out:
#        show_id   type                                         title  \
# 0        10192  Movie                           Shrek Forever After
# 1        27205  Movie                                     Inception
# 2        12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3        38757  Movie                                       Tangled
# 4        10191  Movie                      How to Train Your Dragon
# ...        ...    ...                                           ...
# 15995  1440286  Movie         Festival de Viña del Mar 2025: Ha*Ash
# 15996  1271724  Movie                                 Man and Woman
# 15997  1426364  Movie              Night of the Dead Sorority Babes
# 15998  1411248  Movie                               A Dunces Burden
# 15999  1405742  Movie                                Portal to Hell
#
#                                     director  \
# 0                              Mike Mitchell
# 1                          Christopher Nolan
# ...

# %%
# DUPLICATE REMOVE PARMANENT
df.drop_duplicates(inplace=True)

# %%
# CHECK
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, cast, country, date_added, release_year, rating, duration, genres, language, description, popularity, vote_count, vote_average, budget, revenue]
# Index: []

# %%
df.shape
# Out:
# (16000, 18)

# %%
# CHECK NULL VALUE AND SHOW IT USING HEAT MAP
df.isnull()
# Out:
#        show_id   type  title  director   cast  country  date_added  \
# 0        False  False  False     False  False    False       False
# 1        False  False  False     False  False    False       False
# 2        False  False  False     False  False    False       False
# 3        False  False  False     False  False    False       False
# 4        False  False  False     False  False    False       False
# ...        ...    ...    ...       ...    ...      ...         ...
# 15995    False  False  False      True  False    False       False
# 15996    False  False  False     False  False    False       False
# 15997    False  False  False     False  False     True       False
# 15998    False  False  False     False  False     True       False
# 15999    False  False  False     False  False    False       False
#
#        release_year  rating  duration  genres  language  description  \
# 0             False   False      True   False     False        False
# ...

# %%
# COUNT OF ALL NULL VALUES
df.isnull().sum()
# Out:
# show_id             0
# type                0
# title               0
# director          132
# cast              204
# country           466
# date_added          0
# release_year        0
# rating              0
# duration        16000
# genres            107
# language            0
# description       132
# popularity          0
# vote_count          0
# vote_average        0
# budget              0
# revenue             0
# dtype: int64

# %%
# SHOW THE NULL VALUE USING HEAT MAP ( SEABORN LIBRARY)
import seaborn as sns

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# IF ANY COLUMN HAS TOTAL NULL THEN REMOVE IT
df_mod=df.drop('duration',axis=1)

# %%
df_mod.isnull().sum()
# Out:
# show_id           0
# type              0
# title             0
# director        132
# cast            204
# country         466
# date_added        0
# release_year      0
# rating            0
# genres          107
# language          0
# description     132
# popularity        0
# vote_count        0
# vote_average      0
# budget            0
# revenue           0
# dtype: int64

# %%
sns.heatmap(df_mod.isnull())
# Out:
# <Axes: >

# %%
# FIND ANY SPACIFIC SHOW AND FIND SOME DEATILS
# ISIN() --> FUNCTION
df.head()
# Out:
#    show_id   type                                         title  \
# 0    10192  Movie                           Shrek Forever After
# 1    27205  Movie                                     Inception
# 2    12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3    38757  Movie                                       Tangled
# 4    10191  Movie                      How to Train Your Dragon
#
#                       director  \
# 0                Mike Mitchell
# 1            Christopher Nolan
# 2                  David Yates
# 3   Byron Howard, Nathan Greno
# 4  Chris Sanders, Dean DeBlois
#
#                                                 cast  \
# 0  Mike Myers, Eddie Murphy, Cameron Diaz, Antoni...
# 1  Leonardo DiCaprio, Joseph Gordon-Levitt, Ken W...
# 2  Daniel Radcliffe, Emma Watson, Rupert Grint, T...
# 3  Mandy Moore, Zachary Levi, Donna Murphy, Ron P...
# 4  Jay Baruchel, Gerard Butler, Craig Ferguson, A...
#
# ...

# %%
df[df['title'].isin(['X'])]
# Out:
#        show_id   type title    director  \
# 1093     73454  Movie     X  Jon Hewitt
# 12053   760104  Movie     X     Ti West
#
#                                                     cast  \
# 1093   Viva Bianca, Hanna Mangan Lawrence, Peter Dock...
# 12053  Mia Goth, Jenna Ortega, Brittany Snow, Kid Cud...
#
#                         country  date_added  release_year  rating  duration  \
# 1093                  Australia  2011-11-23          2011   6.466       NaN
# 12053  United States of America  2022-03-17          2022   6.700       NaN
#
#                           genres language  \
# 1093   Action, Thriller, Romance       en
# 12053  Horror, Mystery, Thriller       en
#
#                                              description  popularity  \
# 1093   A veteran call girl and a runaway prostitute w...      23.529
# 12053  In 1979, a group of young filmmakers set out t...      53.229
#
#        vote_count  vote_average   budget   revenue
# ...

# %%
# IF MOVIE NAMES ARE SAME AND WE HAVE ALSO WANT THE SPACIFIC YEAR
df[(df['title'] == 'X') & (df['release_year'] == 2022)]
# Out:
#        show_id   type title director  \
# 12053   760104  Movie     X  Ti West
#
#                                                     cast  \
# 12053  Mia Goth, Jenna Ortega, Brittany Snow, Kid Cud...
#
#                         country  date_added  release_year  rating  duration  \
# 12053  United States of America  2022-03-17          2022     6.7       NaN
#
#                           genres language  \
# 12053  Horror, Mystery, Thriller       en
#
#                                              description  popularity  \
# 12053  In 1979, a group of young filmmakers set out t...      53.229
#
#        vote_count  vote_average   budget   revenue
# 12053        3420           6.7  1000000  15113105

# %%
# STR.CONTENTS() --> WHICH CONTAINS A LETTER ('X') FROM A SENTENCE 
df[df['title'].str.contains('X')]
# Out:
#        show_id   type                                              title  \
# 140     399897  Movie                        Siren XXX: Magical Pleasure
# 528      82628  Movie                              Xtinction: Predator X
# 711      41535  Movie                                      Future X-Cops
# 740      41520  Movie                                       Chico Xavier
# 950      57869  Movie  Pretty Cure All Stars DX2: The Light of Hope -...
# 1093     73454  Movie                                                  X
# 1388     84228  Movie                                            Julia X
# 1648     84155  Movie  Pretty Cure All Stars DX3: Deliver the Future!...
# 1851     85438  Movie                               Paranormal Xperience
# 2020     57214  Movie                                          Project X
# 2696    691677  Movie                    X-Men: First Class 35mm Special
# 2873    139659  Movie                       Puppet Master X: Axis Rising
# ...

# %%
df[df['title'].str.contains('Bad Teacher')]
# Out:
#       show_id   type        title     director  \
# 1099    52449  Movie  Bad Teacher  Jake Kasdan
#
#                                                    cast  \
# 1099  Cameron Diaz, Jason Segel, Justin Timberlake, ...
#
#                        country  date_added  release_year  rating  duration  \
# 1099  United States of America  2011-05-16          2011     5.6       NaN
#
#       genres language                                        description  \
# 1099  Comedy       en  A lazy, incompetent middle school teacher who ...
#
#       popularity  vote_count  vote_average    budget    revenue
# 1099      22.234        4713           5.6  20000000  216197492

# %%
# HIGHEST NO OF MOVIE RELEASE YEAR , HIGHEST rating ,HIGHEST popularity , HIGHEST revenue AND SHOW IT USING BAR CHART
df.dtypes
# Out:
# show_id           int64
# type             object
# title            object
# director         object
# cast             object
# country          object
# date_added       object
# release_year      int64
# rating          float64
# duration        float64
# genres           object
# language         object
# description      object
# popularity      float64
# vote_count        int64
# vote_average    float64
# budget            int64
# revenue           int64
# dtype: object

# %%
# CHANGE THE DATA TYPES ( OBJECT TO DATE TIME)
df['date_N']=pd.to_datetime(df['date_added'])

# %%
df.dtypes
# Out:
# show_id                  int64
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                 float64
# duration               float64
# genres                  object
# language                object
# description             object
# popularity             float64
# vote_count               int64
# vote_average           float64
# budget                   int64
# revenue                  int64
# date_N          datetime64[ns]
# dtype: object

# %%
# 1. COUNT ALL INDIVIDUAL YEAR
df['date_N'].dt.year.value_counts()
# Out:
# date_N
# 2010    1000
# 2011    1000
# 2012    1000
# 2013    1000
# 2014    1000
# 2015    1000
# 2016    1000
# 2017    1000
# 2018    1000
# 2019    1000
# 2020    1000
# 2021    1000
# 2022    1000
# 2023    1000
# 2024    1000
# 2025    1000
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
# BAR CHART
df['date_N'].dt.year.value_counts().plot(kind='bar',color='red')
# Out:
# <Axes: xlabel='date_N'>

# %%
# HIGHEST rating (movie with highest rating)
df.loc[df['rating'].idxmax()]
# Out:
# show_id                                      546026
# type                                          Movie
# title             Inácio Garapa, Um Matuto Sonhador
# director                                   J. Gomes
# cast            Wellington Marques, Maria Elivanete
# country                                         NaN
# date_added                               2010-05-24
# release_year                                   2010
# rating                                         10.0
# duration                                        NaN
# genres                        Comedy, Drama, Family
# language                                         pt
# description                                     NaN
# popularity                                    4.553
# vote_count                                        1
# vote_average                                   10.0
# budget                                            0
# revenue                                           0
# ...

# %%
# 2. COUNT OF MOVIES BY RATING BINS (group ratings into ranges)
pd.cut(df['rating'], bins=[0, 2, 4, 6, 8, 10]).value_counts()
# Out:
# rating
# (6, 8]     9266
# (4, 6]     5118
# (8, 10]     364
# (2, 4]      304
# (0, 2]       49
# Name: count, dtype: int64

# %%
pd.cut(df['rating'], bins=[0, 2, 4, 6, 8, 10]).value_counts().plot(kind='bar',color='yellow')
# Out:
# <Axes: xlabel='rating'>

# %%
# HIGHEST popularity (movie with highest popularity)
df.loc[df['popularity'].idxmax()]
# Out:
# show_id                                                    950396
# type                                                        Movie
# title                                                   The Gorge
# director                                         Scott Derrickson
# cast            Miles Teller, Anya Taylor-Joy, Sigourney Weave...
# country                                  United States of America
# date_added                                             2025-02-13
# release_year                                                 2025
# rating                                                      7.785
# duration                                                      NaN
# genres                         Romance, Science Fiction, Thriller
# language                                                       en
# description     Two highly trained operatives grow close from ...
# popularity                                               3876.006
# ...

# %%
# 3. COUNT OF MOVIES BY POPULARITY BINS
bins = list(range(0, 101, 10))
pd.cut(df['popularity'], bins=bins).value_counts()
# Out:
# popularity
# (0, 10]      7018
# (10, 20]     5752
# (20, 30]     1395
# (30, 40]      567
# (40, 50]      342
# (50, 60]      217
# (60, 70]      152
# (70, 80]      119
# (80, 90]       85
# (90, 100]      50
# Name: count, dtype: int64

# %%
pd.cut(df['popularity'], bins=bins).value_counts().plot(kind='bar',color='black')
# Out:
# <Axes: xlabel='popularity'>

# %%
# HIGHEST revenue (movie with highest revenue)
df.loc[df['revenue'].idxmax()]
# Out:
# show_id                                                    299534
# type                                                        Movie
# title                                           Avengers: Endgame
# director                                 Anthony Russo, Joe Russo
# cast            Robert Downey Jr., Chris Evans, Mark Ruffalo, ...
# country                                  United States of America
# date_added                                             2019-04-24
# release_year                                                 2019
# rating                                                        8.2
# duration                                                      NaN
# genres                         Adventure, Science Fiction, Action
# language                                                       en
# description     After the devastating events of Avengers: Infi...
# popularity                                                133.255
# ...

# %%
# CHANGE THE Values (0000000 to 0.000M)
df['Rev'] = (df['revenue'] / 1_000_000).apply(lambda x: f'{x:.3f}M')
df
# Out:
#        show_id   type                                         title  \
# 0        10192  Movie                           Shrek Forever After
# 1        27205  Movie                                     Inception
# 2        12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3        38757  Movie                                       Tangled
# 4        10191  Movie                      How to Train Your Dragon
# ...        ...    ...                                           ...
# 15995  1440286  Movie         Festival de Viña del Mar 2025: Ha*Ash
# 15996  1271724  Movie                                 Man and Woman
# 15997  1426364  Movie              Night of the Dead Sorority Babes
# 15998  1411248  Movie                               A Dunces Burden
# 15999  1405742  Movie                                Portal to Hell
#
#                                     director  \
# 0                              Mike Mitchell
# 1                          Christopher Nolan
# ...

# %%
# 4. COUNT OF MOVIES BY REVENUE BINS
bins = list(range(0, 1001, 100))
pd.cut(df['revenue'] / 1_000_000, bins=bins).value_counts()
# Out:
# revenue
# (0, 100]       4749
# (100, 200]      381
# (200, 300]      175
# (300, 400]       97
# (400, 500]       65
# (500, 600]       36
# (700, 800]       31
# (600, 700]       30
# (800, 900]       20
# (900, 1000]      12
# Name: count, dtype: int64

# %%
pd.cut(df['revenue'] / 1_000_000, bins=bins).value_counts().plot(kind='bar',color='green')
# Out:
# <Axes: xlabel='revenue'>

# %%
# MOVIE AND TV IN THE DATASET AND SHOW IT USING CHART
df.head()
# Out:
#    show_id   type                                         title  \
# 0    10192  Movie                           Shrek Forever After
# 1    27205  Movie                                     Inception
# 2    12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3    38757  Movie                                       Tangled
# 4    10191  Movie                      How to Train Your Dragon
#
#                       director  \
# 0                Mike Mitchell
# 1            Christopher Nolan
# 2                  David Yates
# 3   Byron Howard, Nathan Greno
# 4  Chris Sanders, Dean DeBlois
#
#                                                 cast  \
# 0  Mike Myers, Eddie Murphy, Cameron Diaz, Antoni...
# 1  Leonardo DiCaprio, Joseph Gordon-Levitt, Ken W...
# 2  Daniel Radcliffe, Emma Watson, Rupert Grint, T...
# 3  Mandy Moore, Zachary Levi, Donna Murphy, Ron P...
# 4  Jay Baruchel, Gerard Butler, Craig Ferguson, A...
#
# ...

# %%
# GROUP BY() with COUNT
df.groupby('type').type.count()
# Out:
# type
# Movie    16000
# Name: type, dtype: int64

# %%
# COUNT PLOT() FUNCTION FOR THE BAR CHART
sns.countplot(
    data=df,
    x='type',
    hue='type',
    palette='viridis',
    edgecolor='black',
    linewidth=1.5,
    legend=False
)
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
# SHOW ALL THE MOVIES ARE RELEASE IN SPACIFIC YEAR
df.head(3)
# Out:
#    show_id   type                                         title  \
# 0    10192  Movie                           Shrek Forever After
# 1    27205  Movie                                     Inception
# 2    12444  Movie  Harry Potter and the Deathly Hallows: Part 1
#
#             director                                               cast  \
# 0      Mike Mitchell  Mike Myers, Eddie Murphy, Cameron Diaz, Antoni...
# 1  Christopher Nolan  Leonardo DiCaprio, Joseph Gordon-Levitt, Ken W...
# 2        David Yates  Daniel Radcliffe, Emma Watson, Rupert Grint, T...
#
#                                     country  date_added  release_year  rating  \
# 0                  United States of America  2010-05-16          2010   6.380
# 1  United Kingdom, United States of America  2010-07-15          2010   8.369
# 2  United Kingdom, United States of America  2010-11-17          2010   7.744
#
#    duration                                         genres language  \
# ...

# %%
df['Year']=df['date_N'].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       16000 non-null  int64
#  1   type          16000 non-null  object
#  2   title         16000 non-null  object
#  3   director      15868 non-null  object
#  4   cast          15796 non-null  object
#  5   country       15534 non-null  object
#  6   date_added    16000 non-null  object
#  7   release_year  16000 non-null  int64
#  8   rating        16000 non-null  float64
#  9   duration      0 non-null      float64
#  10  genres        15893 non-null  object
#  11  language      16000 non-null  object
#  12  description   15868 non-null  object
#  13  popularity    16000 non-null  float64
#  14  vote_count    16000 non-null  int64
#  15  vote_average  16000 non-null  float64
#  16  budget        16000 non-null  int64
#  17  revenue       16000 non-null  int64
# ...

# %%
df.head()
# Out:
#    show_id   type                                         title  \
# 0    10192  Movie                           Shrek Forever After
# 1    27205  Movie                                     Inception
# 2    12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3    38757  Movie                                       Tangled
# 4    10191  Movie                      How to Train Your Dragon
#
#                       director  \
# 0                Mike Mitchell
# 1            Christopher Nolan
# 2                  David Yates
# 3   Byron Howard, Nathan Greno
# 4  Chris Sanders, Dean DeBlois
#
#                                                 cast  \
# 0  Mike Myers, Eddie Murphy, Cameron Diaz, Antoni...
# 1  Leonardo DiCaprio, Joseph Gordon-Levitt, Ken W...
# 2  Daniel Radcliffe, Emma Watson, Rupert Grint, T...
# 3  Mandy Moore, Zachary Levi, Donna Murphy, Ron P...
# 4  Jay Baruchel, Gerard Butler, Craig Ferguson, A...
#
# ...

# %%
# FILTER
df[(df['type'] == 'Movie') & (df['Year'] == 2015)]
# Out:
#       show_id   type                        title  \
# 5000   216015  Movie         Fifty Shades of Grey
# 5001   135397  Movie               Jurassic World
# 5002   150540  Movie                   Inside Out
# 5003   150689  Movie                   Cinderella
# 5004    76341  Movie           Mad Max: Fury Road
# ...       ...    ...                          ...
# 5995   214256  Movie                   AfterDeath
# 5996   352188  Movie                I'm All Yours
# 5997   319067  Movie              Best of Enemies
# 5998   369245  Movie  The Complexity of Happiness
# 5999   179150  Movie                      Reality
#
#                            director  \
# 5000             Sam Taylor-Johnson
# 5001                Colin Trevorrow
# 5002                    Pete Docter
# 5003                Kenneth Branagh
# 5004                  George Miller
# ...                             ...
# 5995    Gez Medinger, Robin Schmidt
# 5996                     Baya Kasmi
# ...

# %%
# TV SHOWS AND MOVIE WHICH RELEASE IN SPACIFIC AREA (title only)
# FILTER
df[(df['type'] == 'Movie') &(df['country'] == 'India')][['title','rating']]
# Out:
#                          title  rating
# 291                   Enthiran     6.6
# 372                      Kites     7.2
# 389    Karthik Calling Karthik     6.2
# 452                    Dabangg     5.8
# 455                  Housefull     5.7
# ...                        ...     ...
# 15877                Vanangaan     4.5
# 15884             Get-Set Baby     0.0
# 15906                Butterfly    10.0
# 15920                    Azaad     7.0
# 15948        Fussclass Dabhade     0.0
#
# [419 rows x 2 columns]

# %%
# TOP 15 DIRECTORS WHO GAVE HIGHEST NO. OF MOVIE OR SHOWS
# VALUE COUNTS
df['director'].value_counts().head(15)
# Out:
# director
# Tyler Perry          20
# Sean McNamara        15
# Steven Soderbergh    15
# Roel Reiné           15
# Choi Woo-seong       14
# Jesse V. Johnson     13
# Don Michael Paul     13
# Choi Jin-chul        13
# Ernie Barbarash      13
# Tosca Musk           13
# Sam Liu              13
# Peter Sullivan       13
# Richard Kim          13
# Steven C. Miller     12
# Alex Zamm            12
# Name: count, dtype: int64

# %%
# Directors with more than 15 movies/series
df['director'].value_counts()[df['director'].value_counts() >= 15]
# Out:
# director
# Tyler Perry          20
# Sean McNamara        15
# Steven Soderbergh    15
# Roel Reiné           15
# Name: count, dtype: int64

# %%
# MOVIE AND TYPE IS COMEDIES OR SPECIFIC COUNTRY
df[(df['type']== 'Movie') & (df['genres']=='Comedy')]
# Out:
#        show_id   type                                         title  \
# 8        38365  Movie                                     Grown Ups
# 80       37735  Movie                                        Easy A
# 136      34803  Movie                            Death at a Funeral
# 178      47407  Movie                                          Milf
# 261      38778  Movie                           Dinner for Schmucks
# ...        ...    ...                                           ...
# 15891   842931  Movie                                    Sacramento
# 15894  1417677  Movie                    Bill Burr: Drop Dead Years
# 15907  1440231  Movie  Festival de Viña del Mar 2025: Chiqui Aguayo
# 15924  1430137  Movie                                 Baba I'm Fine
# 15958  1235619  Movie                 Les Bodin’s partent en vrille
#
#                  director                                               cast  \
# ...

# %%
df[(df['type']== 'Movie') & (df['genres']=='Comedy') | (df['country'] == 'Spain')]
# Out:
#        show_id   type                                         title  \
# 8        38365  Movie                                     Grown Ups
# 17       61979  Movie                      Three Steps Above Heaven
# 80       37735  Movie                                        Easy A
# 136      34803  Movie                            Death at a Funeral
# 178      47407  Movie                                          Milf
# ...        ...    ...                                           ...
# 15907  1440231  Movie  Festival de Viña del Mar 2025: Chiqui Aguayo
# 15924  1430137  Movie                                 Baba I'm Fine
# 15958  1235619  Movie                 Les Bodin’s partent en vrille
# 15973  1436763  Movie                                 Sacra Lunaria
# 15986  1427811  Movie                          La casa y el ternero
#
#                        director  \
# 8                  Dennis Dugan
# 17     Fernando González Molina
# 80                   Will Gluck
# ...

# %%
# HOW MANY MOVIE/SHOWS A SPECIFIC ACTOR DID
df[df['cast'].str.contains('Emma Watson', na=False)]
# Out:
#        show_id   type                                              title  \
# 2        12444  Movie       Harry Potter and the Deathly Hallows: Part 1
# 1000     12445  Movie       Harry Potter and the Deathly Hallows: Part 2
# 1231    483898  Movie                   50 Greatest Harry Potter Moments
# 2049     84892  Movie                    The Perks of Being a Wallflower
# 3283     96936  Movie                                     The Bling Ring
# 4074     86834  Movie                                               Noah
# 5161    241257  Movie                                         Regression
# 5173    318781  Movie                                            Colonia
# 7006    321612  Movie                               Beauty and the Beast
# 7200    339988  Movie                                         The Circle
# 9053    331482  Movie                                       Little Women
# 12063   899082  Movie  Harry Potter 20th Anniversary: Return to Hogwarts
#
# ...

# %%
# DIFF RATING DEFINED BY NETFLIX
# NUNNIQUE FUNCTION
df['rating'].nunique()
# Out:
# 2145

# %%
# sorted UNIQUE RATING
sorted(df['rating'].unique())
# Out:
# [0.0,
#  1.0,
#  1.5,
#  1.8,
#  1.899,
#  2.0,
#  2.056,
#  2.1,
#  2.187,
#  2.2,
#  2.3,
#  2.4,
#  2.5,
#  2.6,
#  2.7,
#  2.8,
#  2.804,
#  2.9,
#  2.949,
#  2.959,
#  2.962,
#  3.0,
#  3.1,
#  3.155,
#  3.2,
#  3.237,
#  3.289,
#  3.3,
#  3.333,
#  3.386,
#  3.4,
#  3.5,
#  3.558,
#  3.567,
#  3.591,
#  3.6,
#  3.611,
#  3.618,
#  3.647,
#  3.658,
#  3.667,
#  3.675,
#  3.681,
#  3.683,
#  3.697,
#  3.7,
#  3.707,
#  3.722,
#  3.732,
#  3.735,
#  3.771,
#  3.774,
#  3.793,
#  3.8,
#  3.813,
#  3.821,
#  3.868,
#  3.9,
#  3.908,
#  3.918,
#  3.925,
#  3.95,
#  3.974,
#  3.978,
#  4.0,
#  4.007,
#  4.054,
#  4.06,
#  4.074,
#  4.083,
#  4.087,
#  4.1,
#  4.105,
#  4.108,
#  4.129,
#  4.14,
#  4.163,
#  4.167,
#  4.171,
#  4.179,
#  4.185,
#  4.19,
#  4.2,
#  4.203,
#  4.209,
#  4.219,
#  4.245,
#  4.247,
#  4.25,
#  4.257,
#  4.281,
#  4.283,
#  4.299,
#  4.3,
#  4.307,
#  4.314,
#  4.318,
#  4.335,
#  4.339,
#  4.355,
#  4.367,
#  4.369,
#  4.375,
#  4.393,
#  4.4,
#  4.417,
# ...

# %%
# Filter rows with rating greater than 7
df[df['rating'] > 7.5]
# Out:
#        show_id   type                                         title  \
# 1        27205  Movie                                     Inception
# 2        12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3        38757  Movie                                       Tangled
# 4        10191  Movie                      How to Train Your Dragon
# 5        11324  Movie                                Shutter Island
# ...        ...    ...                                           ...
# 15897  1245728  Movie                                       Peacock
# 15906  1440249  Movie                                     Butterfly
# 15926  1436457  Movie                          F1 75 Live at The O2
# 15952  1413196  Movie                                 The Wish Swap
# 15956  1434243  Movie                           The Wrong Obsession
#
#                           director  \
# 1                Christopher Nolan
# 2                      David Yates
# 3       Byron Howard, Nathan Greno
# ...

# %%
# SPECIFIC RATING AND COUNTRY
# df[(df['type']== 'Movie') & (df['rating']== 7) & (df['country']=='India')].shape
df[(df['rating'] >= 8) & (df['country']=='India')]
# Out:
#        show_id   type                  title            director  \
# 13308  1139698  Movie                   Toby   Basil Alchalakkal
# 13413  1163258  Movie              12th Fail  Vidhu Vinod Chopra
# 15140  1195430  Movie                   Deva    Rosshan Andrrews
# 15141  1226572  Movie  Superboys of Malegaon         Reema Kagti
# 15280  1273049  Movie                 Dragon   Ashwath Marimuthu
# 15389  1196942  Movie   Mere Husband Ki Biwi       Mudassar Aziz
# 15611   955496  Movie                  Fateh           Sonu Sood
# 15906  1440249  Movie              Butterfly              Monish
#
#                                                     cast country  date_added  \
# 13308  Raj B Shetty, Chaithra J Achar, Samyukta Horna...   India  2023-08-25
# 13413  Vikrant Massey, Medha Shankr, Anant Joshi, Ans...   India  2023-08-11
# 15140  Shahid Kapoor, Pooja Hegde, Pavail Gulati, Pra...   India  2025-01-31
# ...

# %%
# RATING AND YEAR
df[(df['type']== 'Movie') & (df['rating'] > 9) & (df['release_year'] > 2024)]
# df[(df['type']== 'Movie') & (df['rating'] > 9) & (df['release_year'] > 2024)].shape
# Out:
#        show_id   type                                 title  \
# 15186   974573  Movie                  Another Simple Favor
# 15187  1144932  Movie                     Queen of the Ring
# 15280  1273049  Movie                                Dragon
# 15346  1191815  Movie                 The American Backyard
# 15389  1196942  Movie                  Mere Husband Ki Biwi
# 15439  1192174  Movie                              The Kite
# 15494  1313003  Movie                           Close To Me
# 15519  1211726  Movie                              Red Silk
# 15520  1412569  Movie                      Hiram na Sandali
# 15529  1033023  Movie                       Nobody Likes Me
# 15646  1421982  Movie                Lore Of The Ring Light
# 15674  1425662  Movie  Real Madrid: Cómo no te voy a querer
# 15758  1310741  Movie              A Brother and 7 Siblings
# 15792  1352874  Movie                          The Crucifix
# 15906  1440249  Movie                             Butterfly
# ...

# %%
# MAX popularity	
df['popularity'].unique()
# Out:
# array([203.893, 156.242, 121.191, ...,   4.946,   4.943,   4.938])

# %%
df.popularity.dtypes
# Out:
# dtype('float64')

# %%
# str.split() --> Min & Unit
# df['Minutes','Unit'] = df['Duration'].str.split('',expend='True')

# MAX
# df.Minutes.max()

# Min
# df.Minutes.min()

# Mode
# df.Minutes.mode()

# %%
# INDIVISUAL COUNTRY HIGHEST NO. OF MOVIE OR TV SHOW

df_movie=df[df['type']=='Movie']
df_movie.head(3)
# Out:
#    show_id   type                                         title  \
# 0    10192  Movie                           Shrek Forever After
# 1    27205  Movie                                     Inception
# 2    12444  Movie  Harry Potter and the Deathly Hallows: Part 1
#
#             director                                               cast  \
# 0      Mike Mitchell  Mike Myers, Eddie Murphy, Cameron Diaz, Antoni...
# 1  Christopher Nolan  Leonardo DiCaprio, Joseph Gordon-Levitt, Ken W...
# 2        David Yates  Daniel Radcliffe, Emma Watson, Rupert Grint, T...
#
#                                     country  date_added  release_year  rating  \
# 0                  United States of America  2010-05-16          2010   6.380
# 1  United Kingdom, United States of America  2010-07-15          2010   8.369
# 2  United Kingdom, United States of America  2010-11-17          2010   7.744
#
#    duration  ... language                                        description  \
# ...

# %%
df_movie.country.value_counts()
# Out:
# country
# United States of America                                                                            5421
# Japan                                                                                                845
# South Korea                                                                                          789
# France                                                                                               612
# United Kingdom                                                                                       581
#                                                                                                     ...
# New Zealand, Canada                                                                                    1
# Canada, Germany, Norway, Sweden                                                                        1
# France, India                                                                                          1
# ...

# %%
df_movie.country.value_counts().head(1)
# Out:
# country
# United States of America    5421
# Name: count, dtype: int64

# %%
# SORT THE DATASET BY YEAR
df.sort_values(by='release_year').head(5)
# Out:
#      show_id   type                     title                       director  \
# 0      10192  Movie       Shrek Forever After                  Mike Mitchell
# 658    46718  Movie  DC Showcase: Green Arrow             Joaquim Dos Santos
# 659    62756  Movie                    Singam                           Hari
# 660    56529  Movie          The Violent Kind  Phil Flores, Mitchell Altieri
# 661    67560  Movie            Yuriko's Aroma                   Kōta Yoshida
#
#                                                   cast  \
# 0    Mike Myers, Eddie Murphy, Cameron Diaz, Antoni...
# 658  Neal McDonough, Malcolm McDowell, Steve Blum, ...
# 659  Suriya, Anushka Shetty, Prakash Raj, Nassar, V...
# 660  Cory Knauf, Taylor Cole, Bret Roberts, Christi...
# 661  Noriko Eguchi, Shota Sometani, Noriko Kijima, ...
#
#                       country  date_added  release_year  rating  duration  \
# 0    United States of America  2010-05-16          2010   6.380       NaN
# ...

# %%
df.sort_values(by='release_year',ascending = False).head(5)
# Out:
#        show_id   type                           title  \
# 15999  1405742  Movie                  Portal to Hell
# 15328  1399244  Movie      Simon Talbot: Ekstra Extra
# 15341  1297763  Movie  Batman Ninja vs. Yakuza League
# 15340  1138518  Movie   Setan Botak di Jembatan Ancol
# 15339  1421786  Movie              Psychic Manjara 50
#
#                              director  \
# 15999                      Woody Bess
# 15328                             NaN
# 15341  Jumpei Mizusaki, Shinji Takagi
# 15340                    Anggy Umbara
# 15339                             NaN
#
#                                                     cast  \
# 15999  Trey Holland, Keith David, Richard Kind, Micha...
# 15328                                       Simon Talbot
# 15341  Koichi Yamadera, Yuki Kaji, Kengo Kawanishi, D...
# 15340  Ozy Syahputra, Indah Permatasari, Jameelah Sal...
# 15339                                        Saori Otaki
#
# ...

# %%
# TYPE = MOVIES AND genres = DRAMAS
df[(df['type'] == "Movie") & (df['genres']=='Drama')].head(4)
# Out:
#      show_id   type               title           director  \
# 16     37799  Movie  The Social Network      David Fincher
# 110    63319  Movie         Belle épine  Rebecca Zlotowski
# 118    65496  Movie    Student Services  Emmanuelle Bercot
# 129    45317  Movie         The Fighter   David O. Russell
#
#                                                   cast  \
# 16   Jesse Eisenberg, Andrew Garfield, Armie Hammer...
# 110  Léa Seydoux, Anaïs Demoustier, Johan Libéreau,...
# 118  Déborah François, Mathieu Demy, Alain Cauchi, ...
# 129  Mark Wahlberg, Christian Bale, Amy Adams, Meli...
#
#                       country  date_added  release_year  rating  duration  \
# 16   United States of America  2010-10-01          2010   7.368       NaN
# 110                    France  2010-11-10          2010   5.500       NaN
# 118                    France  2010-01-18          2010   5.300       NaN
# 129  United States of America  2010-12-10          2010   7.400       NaN
#
# ...

# %%
# type & language
df[(df['type'] == "Movie") & (df['language']=='en')].head(4)
# Out:
#    show_id   type                                         title  \
# 0    10192  Movie                           Shrek Forever After
# 1    27205  Movie                                     Inception
# 2    12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3    38757  Movie                                       Tangled
#
#                      director  \
# 0               Mike Mitchell
# 1           Christopher Nolan
# 2                 David Yates
# 3  Byron Howard, Nathan Greno
#
#                                                 cast  \
# 0  Mike Myers, Eddie Murphy, Cameron Diaz, Antoni...
# 1  Leonardo DiCaprio, Joseph Gordon-Levitt, Ken W...
# 2  Daniel Radcliffe, Emma Watson, Rupert Grint, T...
# 3  Mandy Moore, Zachary Levi, Donna Murphy, Ron P...
#
#                                     country  date_added  release_year  rating  \
# 0                  United States of America  2010-05-16          2010   6.380
# ...

# %%
# budget | vote_count & vote_average
df[((df['budget'] >= 1000000) | (df['vote_count'] >= 10000)) & (df['vote_average'] >= 7.5)].head(4)
# Out:
#    show_id   type                                         title  \
# 1    27205  Movie                                     Inception
# 2    12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3    38757  Movie                                       Tangled
# 4    10191  Movie                      How to Train Your Dragon
#
#                       director  \
# 1            Christopher Nolan
# 2                  David Yates
# 3   Byron Howard, Nathan Greno
# 4  Chris Sanders, Dean DeBlois
#
#                                                 cast  \
# 1  Leonardo DiCaprio, Joseph Gordon-Levitt, Ken W...
# 2  Daniel Radcliffe, Emma Watson, Rupert Grint, T...
# 3  Mandy Moore, Zachary Levi, Donna Murphy, Ron P...
# 4  Jay Baruchel, Gerard Butler, Craig Ferguson, A...
#
#                                     country  date_added  release_year  rating  \
# 1  United Kingdom, United States of America  2010-07-15          2010   8.369
# ...

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

# Connection details
username = "root"
password = "sourov11@T"    # contains '@' → must be encoded
host = "localhost"
port = "3306"
database = "netflix"

# Encode password for URL
password_encoded = quote_plus(password)

# Create the SQLAlchemy engine
engine = create_engine(
    f"mysql+pymysql://{username}:{password_encoded}@{host}:{port}/{database}",
    echo=True
)

# Table name
table_name = "movie"

# Load DataFrame into MySQL
try:
    df.to_sql(table_name, con=engine, if_exists="replace", index=False)
    print(f"✅ Data loaded successfully into '{table_name}' table.")
except Exception as e:
    print("❌ Error while loading data:", e)
# Out:
# 2025-12-01 16:31:58,011 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2025-12-01 16:31:58,022 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-01 16:31:58,057 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2025-12-01 16:31:58,059 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-01 16:31:58,065 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2025-12-01 16:31:58,067 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-01 16:31:58,079 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-12-01 16:31:58,374 INFO sqlalchemy.engine.Engine DESCRIBE `netflix`.`movie`
# 2025-12-01 16:31:58,379 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-12-01 16:31:58,411 INFO sqlalchemy.engine.Engine
# CREATE TABLE movie (
# 	show_id BIGINT,
# 	type TEXT,
# 	title TEXT,
# 	director TEXT,
# 	cast TEXT,
# 	country TEXT,
# 	date_added TEXT,
# 	release_year BIGINT,
# 	rating FLOAT(53),
# 	duration FLOAT(53),
# 	genres TEXT,
# 	language TEXT,
# 	description TEXT,
# ...
